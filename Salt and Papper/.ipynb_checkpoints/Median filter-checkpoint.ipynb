# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import PIL
import time
from pylab import *

# %%
WINDOW_SIZE = 3
BLOCK_SIZE = 16

# %%
def median_filter_cpu(input_image: np.array, window_size = WINDOW_SIZE) \
                                                                -> np.array:
    height, width = input_image.shape
    mask = []
    counter = window_size // 2
    out_image = np.zeros((height, width))
    for x in range(height):

        for y in range(width):

            for i in range(window_size):
                if x + i - counter < 0 or x + i - counter > height - 1:
                    for j in range(window_size):
                        mask.append(0)
                else:
                    if y + i - counter < 0 or y + counter > width - 1:
                        mask.append(0)
                    else:
                        for j in range(window_size):
                            mask.append(input_image[x + i - counter][y + j - counter])

            mask.sort()
            out_image[x][y] = mask[len(mask) // 2]
            mask = []
    return out_image

# %%
image_path = input("Путь до изображения: ")
image_pil = PIL.Image.open(image_path).convert('L')
image_pil
# Out:
# Путь до изображения: ./data/window_600x400.jpg
# <PIL.Image.Image image mode=L size=600x400 at 0x1E18D364DC0>

# %%
image = np.array(image_pil)
image.shape
# Out:
# (400, 600)

# %%
time_cpu = time.time()
result_cpu = median_filter_cpu(image)
res_im = PIL.Image.fromarray(result_cpu)
axis("off")
imshow(res_im)
time_cpu = time.time() - time.time()
print(f"Time CPU: {round(time_cpu * 1000, 3)} ms")
PIL.Image.fromarray((result_cpu * 255).astype(np.uint32)).save("./images/result_cpu.png")
# Out:
# Time CPU: 0.0 ms

# %%
from pycuda import driver, compiler, gpuarray, tools
import pycuda.autoinit



tools.make_default_context().get_device().name()
# Out:
# 'NVIDIA GeForce GTX 1660'

# %%
import os
if (os.system("cl.exe")):
    os.environ['PATH'] += ';'+r"C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.29.30133\bin\HostX64\x64"
if (os.system("cl.exe")):
    raise RuntimeError("cl.exe still not found, path probably incorrect")

# %%
median_filter_code_kernel = compiler.SourceModule(
    """
texture<unsigned int, cudaTextureType2D, cudaReadModeElementType> texture_ref;
const int COUNT_POINTS = 9;

__global__ void median_filter_kernel(unsigned int* image_out, const int height, const int width) {

    int x = blockIdx.x * blockDim.x + threadIdx.x;
    int y = blockIdx.y * blockDim.y + threadIdx.y;


    if ((x < height) && (y < width)) {
        int mask[COUNT_POINTS];
        int counter = 0;
        
        for (int j = - 1; j <= + 1; j++) {
            for (int i = - 1; i <= + 1; i++) {
                mask[counter] = tex2D(texture_ref, y + i, x + j);
                counter++;
            }
        }
        
        for (int i = 1; i < COUNT_POINTS; i++) {
            for (int j = i; j > 0 && mask[j - 1] > mask[j]; j--) {
                int tmp = mask[j - 1];
                mask[j - 1] = mask[j];
                mask[j] = tmp;
            }
        }

        image_out[x * width + y] = mask[4];

    }
}

    """
)

# %%
def median_filter_gpu(input_image: np.array, window_size = WINDOW_SIZE) -> np.array:
        
        median_filter_kernel = median_filter_code_kernel.get_function("median_filter_kernel")
        
        height, width = input_image.shape
        output_image = np.zeros((height, width), dtype=np.int32)
        
        threads_per_block = (BLOCK_SIZE, BLOCK_SIZE, 1)
        blocks_per_grid = ((height + BLOCK_SIZE - 1) // BLOCK_SIZE, 
                           (width + BLOCK_SIZE - 1) // BLOCK_SIZE)
        
        texture_ref = median_filter_code_kernel.get_texref("texture_ref")
        
        driver.matrix_to_texref(input_image.astype(np.uint32), 
                                texture_ref, 
                                order='C')
        median_filter_kernel(driver.Out(output_image), 
                             np.int32(height), np.int32(width), 
                             texrefs=[texture_ref],
                             block=threads_per_block,
                             grid=blocks_per_grid)
        return output_image

# %%
time_gpu = time.time()
result_gpu = median_filter_gpu(image)
res_im = PIL.Image.fromarray(result_gpu)
axis("off")
imshow(res_im)
time_gpu = time.time() - time.time()
print(f"Time GPU: {round(time_gpu * 1000, 3)} ms")
PIL.Image.fromarray((result_gpu * 255).astype(np.uint32)).save("./images/result_gpu.png")
# Out:
# Time GPU: 0.0 ms

# %%
def test_gpu(image: np.array) -> float:
    height, width = image.shape
    time_local_gpu = time.time()
    median_filter_gpu(image)
    time_local_gpu = time.time() - time_local_gpu
    return time_local_gpu

def test_cpu(image: np.array) -> float:
    height, width = image.shape
    time_local_cpu = time.time()
    median_filter_cpu(image)
    time_local_cpu = time.time() - time_local_cpu
    return time_local_cpu

# %%
from os import listdir
from os.path import isfile, join

IMAGE_DIR = "./data"
image_files = [join(IMAGE_DIR, f) for f in listdir(IMAGE_DIR) if isfile(join(IMAGE_DIR, f))]
data_dict = {
    "shape": [],
    "time_cpu, s": [],
    "time_gpu, s": []
}
for file_path in image_files:
    image = np.array(PIL.Image.open(file_path).convert("L"))
    data_dict["shape"].append(image.shape[0] * image.shape[1])
    data_dict["time_cpu, s"].append(test_cpu(image))
    data_dict["time_gpu, s"].append(test_gpu(image))

# %%
df = pd.DataFrame(data=data_dict)
df["boost"] = df["time_cpu, s"] / df["time_gpu, s"]
df = df.sort_values('shape')
df
# Out:
#       shape  time_cpu, s  time_gpu, s        boost
# 4    240000     1.402259     0.002000   701.096793
# 0   1572864     9.288344     0.006989  1328.949002
# 1   2457600    14.610290     0.009001  1623.268231
# 2   4320000    25.513020     0.020000  1275.652195
# 3  21026304   126.082246     0.086023  1465.683132

# %%
import plotly.express as px

# %%
fig = px.line(df, x="shape", y="time_cpu, s", title='График зависимости времени работы программы на CPU от размера картинки', markers=True)
# fig.write_image("./images/cpu.png")
fig.show()
# Out:
# <div>                            <div id="f282143b-1f3b-4725-b046-18b677ce01da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f282143b-1f3b-4725-b046-18b677ce01da")) {                    Plotly.newPlot(                        "f282143b-1f3b-4725-b046-18b677ce01da",                        [{"hovertemplate":"shape=%{x}<br>time_cpu, s=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[240000,1572864,2457600,4320000,21026304],"xaxis":"x","y":[1.402259111404419,9.288344383239746,14.610290288925171,25.513019561767578,126.08224582672119],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"er
# ...

# %%
fig = px.line(df, x="shape", y="time_gpu, s", title='График зависимости времени работы программы на GPU от размера картинки', markers=True)
# fig.write_image("./images/gpu.png")
fig.show()
# Out:
# <div>                            <div id="54fe7170-16ed-43c4-9358-5898b8d74257" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54fe7170-16ed-43c4-9358-5898b8d74257")) {                    Plotly.newPlot(                        "54fe7170-16ed-43c4-9358-5898b8d74257",                        [{"hovertemplate":"shape=%{x}<br>time_gpu, s=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[240000,1572864,2457600,4320000,21026304],"xaxis":"x","y":[0.002000093460083008,0.006989240646362305,0.009000539779663086,0.019999980926513672,0.08602285385131836],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{
# ...

# %%
fig = px.line(df, x="shape", y="boost", title='График зависимости ускорения от размера картинки', markers=True)
# fig.write_image("./images/boost.png")
fig.show()
# Out:
# <div>                            <div id="089bd2b3-bfa9-41f6-9e27-f27ddcfea82c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("089bd2b3-bfa9-41f6-9e27-f27ddcfea82c")) {                    Plotly.newPlot(                        "089bd2b3-bfa9-41f6-9e27-f27ddcfea82c",                        [{"hovertemplate":"shape=%{x}<br>boost=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[240000,1572864,2457600,4320000,21026304],"xaxis":"x","y":[701.0967934199547,1328.949002217295,1623.268231305131,1275.6521946451137,1465.6831316552386],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":
# ...
